# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings

load_dotenv(override=True)


model_name = os.getenv("MODEL_NAME", "gpt-3.5-turbo")
temperature = float(os.getenv("MODEL_TEMPERATURE", "0"))
project_id = os.getenv("PROJECT_ID")
location = os.getenv("LOCATION", "us-west1")
api_key = os.getenv("VERTEX_API_KEY")



llm = ChatGoogleGenerativeAI(
                model=model_name,
                temperature=temperature,
                project=project_id,
                location=location,
                api_key=api_key,
                vertexai=True,
            )


response = llm.invoke("Hello, world!")
print(response)


embeddings = GoogleGenerativeAIEmbeddings(
                model="text-embedding-005",
                project=project_id,
                location=location,
                api_key=api_key
            )


response = embeddings.embed_query("Hello, world!")
print(response)

# %%
from src.core.deep_agents.graphiti import GraphitiClient

graph_client = GraphitiClient()
await graph_client.initialize()
response = await graph_client.search("National Association of Doctors and Hospital Cardiologists (ANMCO)")
response
# Out:
# [{'fact': 'The national association of doctors and hospital cardiologists (anmco) disseminated a survey to hospital cardiology operative units.',
#   'uuid': '5007a42d-aee1-4af2-a90d-87fb833d26ac',
#   'valid_at': '2024-06-01 00:00:00+00:00',
#   'invalid_at': '2024-10-31 23:59:59+00:00',
#   'source_node_uuid': '411b88c6-a23f-4967-8665-b7f1f0b1ff2c'},
#  {'fact': 'The department of cardiovascular, endocrine-metabolic diseases and aging is part of the Italian national institute of health.',
#   'uuid': '5270511e-c49b-47db-b2c2-3e312aae826c',
#   'valid_at': '2026-01-06 20:52:06.633743+00:00',
#   'invalid_at': None,
#   'source_node_uuid': '09ef3821-2b49-42f1-9b61-970f6c9a849e'},
#  {'fact': 'Cardiology is a category related to acute myocardial infarction.',
#   'uuid': '944c47e6-c5ff-4392-9552-38c4112287e9',
#   'valid_at': '2026-01-06 20:54:11.635156+00:00',
#   'invalid_at': None,
#   'source_node_uuid': 'f6747ef4-473c-42e3-aa92-9dc9f093584d'},
#  {'fact': 'Hospital cardiology operative units were identified through the 8th census of cardiological structures in Italy.',
#   'uuid': 'b7e5c6a9-d24d-42f1-8028-255a0c2d03a1',
#   'valid_at': None,
#   'invalid_at': None,
#   'source_node_uuid': '33379de0-dd2b-4f71-a889-d8c876025a8e'},
#  {'fact': 'Cardiology is a category related to percutaneous coronary intervention.',
#   'uuid': '09357ca6-effb-4753-9e04-aeb124f77210',
#   'valid_at': '2026-01-06 20:54:11.635156+00:00',
#   'invalid_at': None,
#   'source_node_uuid': 'f6747ef4-473c-42e3-aa92-9dc9f093584d'},
#  {'fact': 'Arya Khezrpour is an author of the case report and review of diagnostic and surgical management.',
#   'uuid': '71d2211a-e122-46eb-a474-d09b808cd971',
#   'valid_at': None,
#   'invalid_at': None,
#   'source_node_uuid': '98e55fb7-cb63-4c94-b952-2a07af3e9d27'},
#  {'fact': 'Cardiology is a category related to coronary artery embolism.',
#   'uuid': 'b1fede45-9597-4dd6-ac0b-655a3c2e3445',
#   'valid_at': '2026-01-06 20:54:11.635156+00:00',
#   'invalid_at': None,
#   'source_node_uuid': 'f6747ef4-473c-42e3-aa92-9dc9f093584d'},
#  {'fact': 'Nazanin Rafiei is an author of the case report and review of diagnostic and surgical management.',
#   'uuid': '6c4da190-5eba-41ed-ac98-c8f5e8e3a615',
#   'valid_at': None,
#   'invalid_at': None,
#   'source_node_uuid': 'c641f895-663f-4700-9f14-81125f634ead'},
#  {'fact': 'Cardiology is a category related to pathology.',
#   'uuid': '2d6690ae-d443-440b-a413-cfea22bf4e46',
#   'valid_at': '2026-01-06 20:54:11.635156+00:00',
#   'invalid_at': None,
#   'source_node_uuid': 'f6747ef4-473c-42e3-aa92-9dc9f093584d'},
#  {'fact': 'Pouya Ebrahimi is an author of the case report and review of diagnostic and surgical management.',
#   'uuid': '419c43ed-e008-4e23-b448-8d65423d39b8',
#   'valid_at': None,
#   'invalid_at': None,
#   'source_node_uuid': '66a7c2cf-fd83-43a0-be75-40f9f30ffb98'}]

# %%
from src.core.deep_agent import AgentCore
agent = AgentCore()

result = await agent.ask_async(
    "generate a timeline related to National Association of Doctors and Hospital Cardiologists (ANMCO)"
    )

print(result)
# for msg in result["messages"]:
#     print(msg.pretty_print())
# Out:
# I'm sorry, but I was unable to generate a timeline for the National Association of Doctors and Hospital Cardiologists (ANMCO) from the knowledge graph. The search results provided some facts about their activities, such as disseminating surveys and conducting censuses of cardiology units, but no specific dates or historical events that would allow me to construct a timeline.

# %%
from src.core.deep_agent import AgentCore
agent = AgentCore()

result = await agent.ask_async(
    "Generate a timeline related to coronary thrombi, use the knowledge graph tool"
    )

print(result)
# for msg in result["messages"]:
#     print(msg.pretty_print())
# Out:
# Here's a timeline related to coronary thrombi based on the available information:
#
# *   **2015 - 2019**: Coronary thrombi were retrieved from AMI patients for analysis during this period.
# *   **During analysis**:
#     *   Aspirated thrombi from patients with Coronary Artery Embolism (CE) were found to be significantly "fresher."
#     *   In contrast, 54% of aspirated thrombi from patients without CE were classified as "old."
# *   **Ongoing/Recurrent Events**: Coronary thromboembolic events in patients with Coronary Artery Embolism (CE) tend to be recurrent, multiple, and unpredictable.
# *   **Pathological Study**: The study aims to compare the pathological features of these aspirated thrombi to understand their characteristics better.
# *   **Underlying Conditions**: Coronary Artery Embolism (CE) is identified as an important non-atherosclerotic cause of Acute Myocardial Infarction (AMI).
