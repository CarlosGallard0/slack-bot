# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings

load_dotenv(override=True)


model_name = os.getenv("MODEL_NAME", "gpt-3.5-turbo")
temperature = float(os.getenv("MODEL_TEMPERATURE", "0"))
project_id = os.getenv("PROJECT_ID")
location = os.getenv("LOCATION", "us-west1")
api_key = os.getenv("VERTEX_API_KEY")



llm = ChatGoogleGenerativeAI(
                model=model_name,
                temperature=temperature,
                project=project_id,
                location=location,
                api_key=api_key,
                vertexai=True,
            )


response = llm.invoke("Hello, world!")
print(response)


embeddings = GoogleGenerativeAIEmbeddings(
                model="text-embedding-005",
                project=project_id,
                location=location,
                api_key=api_key
            )


response = embeddings.embed_query("Hello, world!")
print(response)

# %%
from src.core.deep_agents.graphiti import GraphitiClient

graph_client = GraphitiClient()
await graph_client.initialize()
response = await graph_client.search("National Association of Doctors and Hospital Cardiologists (ANMCO)")
response

# %%
from src.core.deep_agents.graphiti import GraphitiClient

graph_client = GraphitiClient()
await graph_client.initialize()
response = await graph_client.search("name: bicuspid aortic valve")
response

# %%
from src.core.deep_agent import AgentCore
agent = AgentCore()

result = await agent.ask_async(
    "generate a timeline related to National Association of Doctors and Hospital Cardiologists (ANMCO)"
    )

print(result)
# for msg in result["messages"]:
#     print(msg.pretty_print())

# %%
from src.core.deep_agent import AgentCore
agent = AgentCore()

result = await agent.ask_async(
    "Generate a timeline related to coronary thrombi, use the knowledge graph tool"
    )

print(result)
# for msg in result["messages"]:
#     print(msg.pretty_print())

# %%
from src.core.deterministic_agent.d_agent import DeterministicAgent

# Initialize the agent
agent = DeterministicAgent()

# Run the query asynchronously
result = await agent.ask_async("Generate a timeline related to coronary thrombi, use the knowledge graph tool")

print(result)
# Out:
# ================================================================================
# FILTERER: Checking if question is medical-related
# ================================================================================
# ✅ Question accepted: Medical topic detected.
#
# ================================================================================
# ORCHESTRATOR: Analyzing question and selecting indexes
# ================================================================================
#
# ✓ Selected 1 indexes for processing:
#   • graphiti_main: The user is asking for a timeline related to 'coronary thrombi' and explicitly mentions using a knowledge graph tool. The 'graphiti_main' index is described as a 'Medical Knowledge Graph' containing information about diseases, treatments, and clinical research, which directly aligns with the query's subject matter (coronary thrombi are a medical condition/disease) and the requested tool type.
#
# ================================================================================
# Assigning 1 workers
# ================================================================================
#
# --------------------------------------------------------------------------------
# WORKER [graphiti_main]: Starting pipeline
# --------------------------------------------------------------------------------
#
# [graphiti_main] Step 1: Initializing Graphiti client...
#
# [graphiti_main] Step 2: Generating search queries...
#   ✓ Generated 5 queries:
#     1. History of coronary thrombosis research and understanding
#     2. Milestones and key discoveries in coronary artery disease pathogenesis related to thrombi
#     3. Development and evolution of treatments for coronary thrombi and myocardial infarction
#     4. Historical context and early theories of myocardial infarction etiology before thrombi understanding
#     5. Evolution of diagnostic methods for coronary artery thrombosis
#
# [graphiti_main] Step 3: Executing queries against Graphiti...
#   ✓ Retrieved 25 total chunks from 5 queries
#
# [graphiti_main] Step 4: Evaluating query quality...
#   ✓ 'History of coronary thrombosis research and understanding' - 5 relevant chunks
#   ✓ 'Milestones and key discoveries in coronary artery disease pathogenesis related to thrombi' - 5 relevant chunks
#   ✓ 'Development and evolution of treatments for coronary thrombi and myocardial infarction' - 5 relevant chunks
#   ✓ 'Historical context and early theories of myocardial infarction etiology before thrombi understanding' - 5 relevant chunks
#   ✓ 'Evolution of diagnostic methods for coronary artery thrombosis' - 5 relevant chunks
#
#   → 5/5 queries passed evaluation
#
# [graphiti_main] Step 5: Deduplicating chunks...
#   ✓ 19 unique chunks (removed 6 duplicates)
#
# [graphiti_main] Step 6: Generating summary from retrieved documents...
#   ✓ Summary generated (728 characters)
#
# [graphiti_main] Step 7: Collecting source references...
#   ✓ 1 unique sources referenced
#
# --------------------------------------------------------------------------------
# WORKER [graphiti_main]: Pipeline complete
#   • Queries: 5/5 passed
#   • Chunks: 19 retrieved
#   • Sources: 1 unique
#   • Summary: 728 characters
# --------------------------------------------------------------------------------
#
# ================================================================================
# SYNTHESIZER: Creating final timeline with consistent formatting
# ================================================================================
#
# ✓ Synthesizing information from all sources...
#
# ✓ Generating research limitations paragraph...
#   ✓ Limitations paragraph generated (673 characters)
#
# ✓ Building source references...
#
# ✓ Final output created:
#   • Timeline: 1142 characters
#   • Limitations: 673 characters
#   • References: 387 characters
#   • Total sources: 1
# ================================================================================
# ================================================================================
# TIMELINE
# ================================================================================
# Based on the information provided, a chronological timeline detailing the historical developments of coronary thrombi cannot be constructed. The available research clarifies the critical role of thrombi in coronary events but does not offer specific dates, historical progression, or developmental milestones related to their understanding or treatment.
#
# The research highlights a direct and crucial link between "thrombotic crises" and the diagnosis of "ST-elevation myocardial infarction" (STEMI). This indicates that thrombi are fundamental in the pathology of this severe form of heart attack. More broadly, the context provided identifies "cardiovascular disease" as encompassing "thrombotic disease," underscoring the pervasive impact of blood clot formation in the cardiovascular system. Furthermore, acute myocardial infarction, a specific type of myocardial infarction, is frequently and significantly associated with these thrombotic events. While this information establishes the profound significance of thrombi in cardiac health, it does not offer the chronological data necessary to build a timeline of their study or discovery.
# ================================================================================
# RESEARCH LIMITATIONS
# ================================================================================
# This research on coronary thrombi exclusively utilized data from the Medical Knowledge Graph, specifically limited to the year 2024. Consequently, it does not incorporate insights from other medical databases, clinical trials published in prior years, or a broader scope of cardiovascular topics beyond coronary thrombi. While all five search queries passed relevance filtering, the extremely narrow temporal window and small dataset of only 19 retrieved information chunks mean these findings are not comprehensive and lack historical context or broader recent developments. This summary should therefore not be considered an exhaustive overview of all available research.
# ================================================================================
# SOURCES & REFERENCES
# ================================================================================
# **Research Metadata:**
# - Question: Generate a timeline related to coronary thrombi, use the knowledge graph tool
# - Indexes analyzed: 1
# - Total chunks retrieved: 19
# - Query success rate: 5/5 (100.0%)
# - Years covered: 2024 - 2024
#
# **Medical Knowledge Graph (2024)**
# Index ID: graphiti_main
# Documents referenced: 1
# Sources:
#   1. Graphiti Knowledge Graph (Topic: General, Relevance: 90.0%)
