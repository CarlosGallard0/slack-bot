# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings

load_dotenv(override=True)


model_name = os.getenv("MODEL_NAME", "gpt-3.5-turbo")
temperature = float(os.getenv("MODEL_TEMPERATURE", "0"))
project_id = os.getenv("PROJECT_ID")
location = os.getenv("LOCATION", "us-west1")
api_key = os.getenv("VERTEX_API_KEY")



llm = ChatGoogleGenerativeAI(
                model=model_name,
                temperature=temperature,
                project=project_id,
                location=location,
                api_key=api_key,
                vertexai=True,
            )


response = llm.invoke("Hello, world!")
print(response)


embeddings = GoogleGenerativeAIEmbeddings(
                model="text-embedding-005",
                project=project_id,
                location=location,
                api_key=api_key
            )


response = embeddings.embed_query("Hello, world!")
print(response)
# Out:
# content='Hello there! How can I help you today?' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019bb881-d35b-79b0-9938-eeb36126cdbf-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 4, 'output_tokens': 44, 'total_tokens': 48, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 34}}
# [-0.042480308562517166, 0.04115406796336174, -0.016070734709501266, -0.04406413808465004, 0.025830749422311783, -0.008029526099562645, 0.05397859215736389, -0.04336094111204147, 0.029898809269070625, -0.003222341649234295, -0.057448457926511765, -0.025035761296749115, -0.006228124722838402, -0.011549506336450577, -0.0031014212872833014, 0.05721123144030571, 0.06262732297182083, -0.04855245351791382, -0.024863189086318016, -0.03651437908411026, -7.9303041275125e-05, -0.039533745497465134, -0.06902997940778732, -0.08136114478111267, 0.027910888195037842, -0.010527143254876137, -0.02710292860865593, -0.03928494453430176, -0.011744477786123753, 0.026184527203440666, 0.01830841414630413, -0.029333017766475677, 0.0034246202558279037, -0.010099798440933228, 0.020626328885555267, 0.0022872446570545435, 0.10691634565591812, -0.01808866299688816, 0.05694062262773514, -0.030216002836823463, -0.014782093465328217, -0.0537983700633049, -0.02928951010107994, -0.019383057951927185, -0.0005676776636391878, 0.04175052419304848, -0.038069359958171844, 0.0033085299655795097, 0.06854414939880371, -0.035870328545570374, 0.029501985758543015, 0.04660052806138992, -0.013079691678285599, -0.0037751991767436266, -0.012136806733906269, 0.06262029707431793, -0.020679470151662827, -0.02032410353422165, 0.03174072876572609, 0.04259400814771652, -0.03675973787903786, -0.06174487993121147, -0.026865681633353233, -0.01641419343650341, -0.017341841012239456, 0.007228738162666559, 0.013659495860338211, 0.005138338077813387, 0.014156901277601719, -0.020431037992239, -0.02980967052280903, 0.003048167796805501, 0.02147289179265499, 0.042404111474752426, -0.0012568309903144836, 0.03822556883096695, 0.026390599086880684, 0.041803937405347824, -0.002483099466189742, -0.02641003020107746, -0.03942503407597542, 0.016502737998962402, -0.038077887147665024, -0.028385687619447708, 0.001885303296148777, -0.031956497579813004, -0.03497937694191933, -0.02521112747490406, -0.009097162634134293, -0.04912685602903366, -0.02253551408648491, 0.001482810010202229, -0.062032654881477356, -0.030325038358569145, -0.001995441038161516, -0.01391960121691227, 0.04099841043353081, 0.04257262125611305, -0.043487660586833954, 0.047067347913980484, 0.03235809504985809, -0.0021098682191222906, -0.055288638919591904, -0.05612417310476303, 0.02056065946817398, 0.055078230798244476, -0.05015312880277634, -0.0392666757106781, 0.0605941042304039, -0.013255047611892223, -0.015756387263536453, -0.0033892206847667694, -0.07395520806312561, 0.03156037628650665, 0.023537538945674896, -0.0013674314832314849, -0.038540318608284, 0.012972595170140266, -0.03792290389537811, -0.040705349296331406, -0.0038181429263204336, -0.03612837940454483, 0.051540836691856384, 0.05451596528291702, -0.006859033368527889, 0.03289983421564102, -0.02991560474038124, 0.02283794991672039, 0.013640972785651684, -0.04334770515561104, -0.002029323484748602, -0.042590394616127014, 0.04923250153660774, 0.10925839841365814, 0.0037993723526597023, 0.004328044131398201, 0.0065475464798510075, -0.013750439509749413, -0.038244932889938354, 0.04542972892522812, -0.029734063893556595, 0.02146061696112156, 0.03981548175215721, 0.04554960876703262, 0.04952754080295563, -0.03913582116365433, -0.08169650286436081, 0.05079559236764908, -0.0072569465264678, -0.01171923242509365, -0.013428499922156334, -0.011969289742410183, -0.04737671837210655, 0.030696792528033257, 0.0607130266726017, -0.06708918511867523, -0.01618281379342079, -0.022293249145150185, 0.007948890328407288, 0.015837397426366806, 0.027034100145101547, 0.018304362893104553, -0.07150661200284958, 0.034580301493406296, 0.009753032587468624, 0.049706894904375076, 0.0832408219575882, -0.029336947947740555, -0.0018357817316427827, 0.02251984179019928, -0.0005896441289223731, 0.04439310356974602, -0.05460729822516441, 0.007722070440649986, 0.06513861566781998, 0.03941559046506882, -0.04559525102376938, 0.013472873717546463, -0.007618295028805733, -0.036440081894397736, -0.0544377751 ...

# %%
from src.core.deep_agents.graphiti import GraphitiClient

graph_client = GraphitiClient()
await graph_client.initialize()
response = await graph_client.search("National Association of Doctors and Hospital Cardiologists (ANMCO)")
response
# Out:
# [{'fact': 'Ajay Pandey collaborated with Rinita Ajey on the concept and design.',
#   'uuid': 'd114f8a9-3eba-4afd-9dee-c6465bf051d3',
#   'valid_at': None,
#   'invalid_at': None,
#   'source_node_uuid': '315722bf-f609-493b-b7b6-a5298112d386'},
#  {'fact': 'Cosgrove DM 3rd authored an article published in Curr Probl Cardiol.',
#   'uuid': 'ff11fc2b-031d-4205-90b2-02e33d68dd7a',
#   'valid_at': '2003-01-01 00:00:00+00:00',
#   'invalid_at': None,
#   'source_node_uuid': '7828d281-87b6-445f-9fda-b5e18ee32aa9'},
#  {'fact': "Nkomo VT co-authored the paper 'Aortic dilatation patterns and rates in adults with bicuspid aortic valves: a comparative study with Marfan syndrome and degenerative aortopathy' with Sarano ME.",
#   'uuid': '19598014-62c5-4d9c-85bf-89a2482614bf',
#   'valid_at': None,
#   'invalid_at': None,
#   'source_node_uuid': '381b8410-58bb-4f7e-938d-de8bea9954ba'},
#  {'fact': 'Rinita Ajey collaborated with Ravindra Varma on the concept and design.',
#   'uuid': 'e3b7c550-b22d-47e9-8c7b-d678fa336c0e',
#   'valid_at': None,
#   'invalid_at': None,
#   'source_node_uuid': '767331b8-86c1-472e-9c1e-0ac91572e378'},
#  {'fact': "Nkomo VT co-authored the paper 'Aortic dilatation patterns and rates in adults with bicuspid aortic valves: a comparative study with Marfan syndrome and degenerative aortopathy' with Vahanian A.",
#   'uuid': '91b71a9a-8b6d-456f-b2ab-1817391cee5d',
#   'valid_at': None,
#   'invalid_at': None,
#   'source_node_uuid': '381b8410-58bb-4f7e-938d-de8bea9954ba'},
#  {'fact': 'Ajay Pandey collaborated with Ravindra Varma on the concept and design.',
#   'uuid': '71211ad0-a017-4c92-adc3-cbab071af034',
#   'valid_at': None,
#   'invalid_at': None,
#   'source_node_uuid': '315722bf-f609-493b-b7b6-a5298112d386'},
#  {'fact': "Jondeau G co-authored the paper 'Aortic dilatation patterns and rates in adults with bicuspid aortic valves: a comparative study with Marfan syndrome and degenerative aortopathy' with Nkomo VT.",
#   'uuid': '138bc36b-2799-459a-93ee-918b5b892eac',
#   'valid_at': None,
#   'invalid_at': None,
#   'source_node_uuid': '5bfc0d7b-c1f9-47e6-a0f7-5c038244bfde'},
#  {'fact': 'Ajay Pandey collaborated with Priyanka Balkhe on the concept and design.',
#   'uuid': 'dc571e77-b4ff-401d-82fe-f88432c5e75f',
#   'valid_at': None,
#   'invalid_at': None,
#   'source_node_uuid': '315722bf-f609-493b-b7b6-a5298112d386'},
#  {'fact': "Detaint D co-authored the paper 'Aortic dilatation patterns and rates in adults with bicuspid aortic valves: a comparative study with Marfan syndrome and degenerative aortopathy' with Nkomo VT.",
#   'uuid': 'ae63b511-4268-463b-845d-46d8798617bf',
#   'valid_at': None,
#   'invalid_at': None,
#   'source_node_uuid': 'cee3afed-b1d6-46eb-96ab-c92108b51bb3'},
#  {'fact': 'Priyanka Balkhe collaborated with Ravindra Varma on the concept and design.',
#   'uuid': '6072cff0-895d-4ba5-bd4a-2bc952c5223c',
#   'valid_at': None,
#   'invalid_at': None,
#   'source_node_uuid': '87ddef46-3db4-4985-a9d8-a7a3cab9dc9a'}]

# %%
from src.core.deep_agents.graphiti import GraphitiClient

graph_client = GraphitiClient()
await graph_client.initialize()
response = await graph_client.search("name: bicuspid aortic valve")
response
# Out:
# [{'fact': 'The article "Clinical significance of the bicuspid aortic valve" discusses the topic of bicuspid aortic valve.',
#   'uuid': 'bea168ff-112d-4f1b-9a7a-9bafd481c9e7',
#   'valid_at': '2000-01-01 00:00:00+00:00',
#   'invalid_at': None,
#   'source_node_uuid': '07b6602a-bd65-416f-8102-514849773bd8'},
#  {'fact': 'The article "Aortic root dilatation in young men with normally functioning bicuspid aortic valves" discusses the topic of bicuspid aortic valve.',
#   'uuid': '8c7fc81b-b23c-4705-ac64-42ff3c9833ab',
#   'valid_at': '1999-01-01 00:00:00+00:00',
#   'invalid_at': None,
#   'source_node_uuid': 'a0412a39-a22f-4f22-8a30-9ca0edf74f3f'},
#  {'fact': 'The article "Clinical significance of the bicuspid aortic valve" was published in Heart.',
#   'uuid': '141bb74b-6651-46ec-99d9-0a2d6276fa33',
#   'valid_at': '2000-01-01 00:00:00+00:00',
#   'invalid_at': None,
#   'source_node_uuid': '07b6602a-bd65-416f-8102-514849773bd8'},
#  {'fact': 'Ward C authored the article titled "Clinical significance of the bicuspid aortic valve".',
#   'uuid': 'da5a457f-dc41-4b03-9cc4-fb80b754ae40',
#   'valid_at': '2000-01-01 00:00:00+00:00',
#   'invalid_at': None,
#   'source_node_uuid': 'ee6ba711-5bd5-4caa-addd-4fc04650519a'},
#  {'fact': 'The article "Aortic root dilatation in young men with normally functioning bicuspid aortic valves" discusses the topic of Aortic root dilatation.',
#   'uuid': '4d4dd204-8ec8-490d-b317-448654ee09a0',
#   'valid_at': '1999-01-01 00:00:00+00:00',
#   'invalid_at': None,
#   'source_node_uuid': 'a0412a39-a22f-4f22-8a30-9ca0edf74f3f'},
#  {'fact': 'The article "Aortic root dilatation in young men with normally functioning bicuspid aortic valves" was published in Heart.',
#   'uuid': 'ccd66cc8-c429-4b88-9197-55b0db314cc6',
#   'valid_at': '1999-01-01 00:00:00+00:00',
#   'invalid_at': None,
#   'source_node_uuid': 'a0412a39-a22f-4f22-8a30-9ca0edf74f3f'},
#  {'fact': 'Nistri S authored the article titled "Aortic root dilatation in young men with normally functioning bicuspid aortic valves".',
#   'uuid': 'ea1dbdd2-48ea-45df-a1c8-77077cd745fa',
#   'valid_at': '1999-01-01 00:00:00+00:00',
#   'invalid_at': None,
#   'source_node_uuid': '0bdad297-84fd-4b8d-9bba-21c756f3ccb7'},
#  {'fact': 'Marin M authored the article titled "Aortic root dilatation in young men with normally functioning bicuspid aortic valves".',
#   'uuid': '4c92c48c-b496-4317-94a4-32965b617960',
#   'valid_at': '1999-01-01 00:00:00+00:00',
#   'invalid_at': None,
#   'source_node_uuid': '84a1b324-4448-40b2-83b2-b9c63c55f8ba'},
#  {'fact': "Ko JM co-authored the paper 'Frequency by decades of unicuspid, bicuspid, and tricuspid aortic valves in adults having isolated aortic valve replacement for aortic stenosis, with or without associated aortic regurgitation' with Roberts WC.",
#   'uuid': 'e6a6bb58-f6a6-4282-ac90-4d2de565b691',
#   'valid_at': '2005-01-01 00:00:00+00:00',
#   'invalid_at': None,
#   'source_node_uuid': '96b7af2c-e1b7-4b43-9857-a18d7171db85'},
#  {'fact': 'Scognamiglio R authored the article titled "Aortic root dilatation in young men with normally functioning bicuspid aortic valves".',
#   'uuid': '25772338-6a11-46fb-bfa5-fbe0732b1830',
#   'valid_at': '1999-01-01 00:00:00+00:00',
#   'invalid_at': None,
#   'source_node_uuid': '6b685080-db83-4ff3-b847-ff5f20cc39cc'}]

# %%
from src.core.deep_agent import AgentCore
agent = AgentCore()

result = await agent.ask_async(
    "generate a timeline related to National Association of Doctors and Hospital Cardiologists (ANMCO)"
    )

print(result)
# for msg in result["messages"]:
#     print(msg.pretty_print())
# Out:
# --- DEBUG: Graph Search Output ---
# Query: timeline of National Association of Doctors and Hospital Cardiologists (ANMCO)
# Results:
# - Fact: The work titled "Regression equations for calculation of z scores of cardiac" discusses the topic of z scores of cardiac.
#   ID: 3086416a-e820-4db4-9049-1f3475a0f48c
# - Fact: Nkomo VT co-authored the paper 'Aortic dilatation patterns and rates in adults with bicuspid aortic valves: a comparative study with Marfan syndrome and degenerative aortopathy' with Sarano ME.
#   ID: 19598014-62c5-4d9c-85bf-89a2482614bf
# - Fact: Pettersen MD authored the work titled "Regression equations for calculation of z scores of cardiac".
#   ID: 16db086e-bbca-4274-a1bd-779164dafa0d
# - Fact: Nkomo VT co-authored the paper 'Aortic dilatation patterns and rates in adults with bicuspid aortic valves: a comparative study with Marfan syndrome and degenerative aortopathy' with Vahanian A.
#   ID: 91b71a9a-8b6d-456f-b2ab-1817391cee5d
# - Fact: Skeens ME authored the work titled "Regression equations for calculation of z scores of cardiac".
#   ID: fc8091ec-ff30-41e5-9cb5-a816d7f4ae5a
# - Fact: Jondeau G co-authored the paper 'Aortic dilatation patterns and rates in adults with bicuspid aortic valves: a comparative study with Marfan syndrome and degenerative aortopathy' with Nkomo VT.
#   ID: 138bc36b-2799-459a-93ee-918b5b892eac
# - Fact: Ko JM co-authored the paper 'Frequency by decades of unicuspid, bicuspid, and tricuspid aortic valves in adults having isolated aortic valve replacement for aortic stenosis, with or without associated aortic regurgitation' with Roberts WC.
#   ID: e6a6bb58-f6a6-4282-ac90-4d2de565b691
# - Fact: Du W authored the work titled "Regression equations for calculation of z scores of cardiac".
#   ID: 6a0719d8-d174-490d-be5d-c9bec12d0bf6
# - Fact: Cosgrove DM 3rd authored an article published in Curr Probl Cardiol.
#   ID: ff11fc2b-031d-4205-90b2-02e33d68dd7a
# - Fact: Humes RA authored the work titled "Regression equations for calculation of z scores of cardiac".
#   ID: 69d62ea7-1a95-4a85-9ca5-1f7089c63251
# ----------------------------------
#
#
# --- DEBUG: Graph Search Output ---
# Query: National Association of Doctors and Hospital Cardiologists (ANMCO)
# Results:
# - Fact: Ajay Pandey collaborated with Rinita Ajey on the concept and design.
#   ID: d114f8a9-3eba-4afd-9dee-c6465bf051d3
# - Fact: Cosgrove DM 3rd authored an article published in Curr Probl Cardiol.
#   ID: ff11fc2b-031d-4205-90b2-02e33d68dd7a
# - Fact: Nkomo VT co-authored the paper 'Aortic dilatation patterns and rates in adults with bicuspid aortic valves: a comparative study with Marfan syndrome and degenerative aortopathy' with Sarano ME.
#   ID: 19598014-62c5-4d9c-85bf-89a2482614bf
# - Fact: Rinita Ajey collaborated with Ravindra Varma on the concept and design.
#   ID: e3b7c550-b22d-47e9-8c7b-d678fa336c0e
# - Fact: Nkomo VT co-authored the paper 'Aortic dilatation patterns and rates in adults with bicuspid aortic valves: a comparative study with Marfan syndrome and degenerative aortopathy' with Vahanian A.
#   ID: 91b71a9a-8b6d-456f-b2ab-1817391cee5d
# - Fact: Ajay Pandey collaborated with Ravindra Varma on the concept and design.
#   ID: 71211ad0-a017-4c92-adc3-cbab071af034
# - Fact: Jondeau G co-authored the paper 'Aortic dilatation patterns and rates in adults with bicuspid aortic valves: a comparative study with Marfan syndrome and degenerative aortopathy' with Nkomo VT.
#   ID: 138bc36b-2799-459a-93ee-918b5b892eac
# - Fact: Ajay Pandey collaborated with Priyanka Balkhe on the concept and design.
#   ID: dc571e77-b4ff-401d-82fe-f88432c5e75f
# - Fact: Detaint D co-authored the paper 'Aortic dilatation patterns and rates in adults with bicuspid aortic valves: a comparative study with Marfan syndrome and degenerative aortopathy' with Nkomo VT.
#   ID: ae63b511-4268-463b-845d-46d8798617bf
# - Fact: Priyanka Balkhe collaborated with Ravindra Varma on the concept and design.
#   ID: 6072cff0-895d-4ba5-bd4a-2bc952c5223c
# ----------------------------------
#
# I'm sorry, but I was unable to generate a timeline for the National Association of Doctors and Hospital Cardiologists (ANMCO) using the available knowledge graph. My searches did not return specific historical information or key dates related to the organization's history. The results primarily focused on medical papers and their authors, rather than the association itself.
#
# It's possible that this specific timeline information is not present in the knowledge graph I can access.

# %%
from src.core.deep_agent import AgentCore
agent = AgentCore()

result = await agent.ask_async(
    "Generate a timeline related to coronary thrombi, use the knowledge graph tool"
    )

print(result)
# for msg in result["messages"]:
#     print(msg.pretty_print())
# Out:
# --- DEBUG: Graph Search Output ---
# Query: timeline of coronary thrombi discoveries, treatments, and understanding
# Results:
# - Fact: Coronary thrombi were retrieved between 2015 and 2019.
#   ID: 4dbd4ac5-267c-4edf-bcc2-aee6e9d33029
# - Fact: Coronary thrombi were analyzed from ami patients.
#   ID: d17f54f4-cf5b-4401-a781-b489db3520b6
# - Fact: Aspirated thrombi were stained with hematoxylin and eosin.
#   ID: 870aaf32-7e6f-4a5d-874a-c1e6fe68ea42
# - Fact: Coronary thromboembolic events tend to be recurrent, multiple, and unpredictable in patients with coronary artery embolism (ce).
#   ID: b7b3b8b9-0fdb-4675-8e68-fa27f6d044dd
# - Fact: There is a review of the diagnostic and surgical management of anomalous right coronary artery.
#   ID: 52a68c58-2d29-4de7-a5f2-2b5646f2f769
# - Fact: Coronary artery embolism (ce) is an important nonatherosclerotic etiology of acute myocardial infarction (ami).
#   ID: b402d8c2-544e-4a21-86d8-a5c7c7d0c242
# - Fact: Functional testing and coronary CT angiography are key for diagnosis and risk stratification.
#   ID: 1ddeb1c7-5e40-459a-9abd-21467f35e198
# - Fact: Cardiology is a category related to coronary artery embolism.
#   ID: b1fede45-9597-4dd6-ac0b-655a3c2e3445
# - Fact: Touba Akbari is an author of the case report and review of diagnostic and surgical management.
#   ID: 68caf2e2-1117-408b-bb76-657832a03039
# - Fact: Cardiology is a category related to aspiration thrombectomy.
#   ID: 9ae42582-b253-4add-a867-7149cd222d6d
# ----------------------------------
#
#
# --- DEBUG: Graph Search Output ---
# Query: history of coronary thrombosis discoveries
# Results:
# - Fact: Coronary thrombi were analyzed from ami patients.
#   ID: d17f54f4-cf5b-4401-a781-b489db3520b6
# - Fact: The 46-year-old woman had a family history of premature coronary disease.
#   ID: a3f7d390-ddb8-41be-ab2b-b0b764c8498c
# - Fact: Coronary artery embolism (ce) is an important nonatherosclerotic etiology of acute myocardial infarction (ami).
#   ID: b402d8c2-544e-4a21-86d8-a5c7c7d0c242
# - Fact: Treatment of coronary steal phenomenon in cases of coronary-lung fistulas can include fistula embolization.
#   ID: 4fbebb3f-da2d-4c7d-841e-51e831ca3f5b
# - Fact: Coronary thromboembolic events tend to be recurrent, multiple, and unpredictable in patients with coronary artery embolism (ce).
#   ID: b7b3b8b9-0fdb-4675-8e68-fa27f6d044dd
# - Fact: Coronary artery anomalies (caas) have a prevalence of 0.17% to 1.3% in angiographic studies of coronary arteries.
#   ID: fd0ce40b-9986-4714-a74c-8201412770b5
# - Fact: Coronary thrombi were retrieved between 2015 and 2019.
#   ID: 4dbd4ac5-267c-4edf-bcc2-aee6e9d33029
# - Fact: Acute coronary syndromes in the presence of coronary-lung fistulas should be considered for coronary steal phenomenon.
#   ID: b39ac8b7-f44d-4bce-8a6c-171a66574368
# - Fact: Cardiology is a category related to coronary artery embolism.
#   ID: b1fede45-9597-4dd6-ac0b-655a3c2e3445
# - Fact: Coronary artery anomalies (caas) are congenital variations in the origin, course, or structure of the coronary arteries.
#   ID: b0c88b1d-fb87-4160-bce2-d8590f56f815
# ----------------------------------
#
#
# --- DEBUG: Graph Search Output ---
# Query: development of treatments for coronary thrombosis
# Results:
# - Fact: Acute coronary syndromes in the presence of coronary-lung fistulas should be considered for coronary steal phenomenon.
#   ID: b39ac8b7-f44d-4bce-8a6c-171a66574368
# - Fact: Coronary thromboembolic events tend to be recurrent, multiple, and unpredictable in patients with coronary artery embolism (ce).
#   ID: b7b3b8b9-0fdb-4675-8e68-fa27f6d044dd
# - Fact: Functional testing and coronary CT angiography are key for diagnosis and risk stratification.
#   ID: 1ddeb1c7-5e40-459a-9abd-21467f35e198
# - Fact: Coronary artery embolism (ce) is an important nonatherosclerotic etiology of acute myocardial infarction (ami).
#   ID: b402d8c2-544e-4a21-86d8-a5c7c7d0c242
# - Fact: Treatment of coronary steal phenomenon in cases of coronary-lung fistulas can include fistula embolization.
#   ID: 4fbebb3f-da2d-4c7d-841e-51e831ca3f5b
# - Fact: Current antiplatelet therapy without anticoagulants may cause coronary thromboembolic events.
#   ID: 2aa7c77a-c086-4c06-a691-2a7db25a50b7
# - Fact: Lack of dedicated staff was a principal obstacle for health professionals.
#   ID: 99f84ac7-cd18-4081-ac9f-ab55430c0f91
# - Fact: Current antiplatelet therapy without anticoagulants may cause coronary thromboembolic events.
#   ID: 8ea20059-fe6c-4b3a-b67a-2a64a55f6b70
# - Fact: Lack of familiarity with technology was the principal obstacle for patients.
#   ID: 9a8a79b7-9b00-4705-928a-1dc8612d15ba
# - Fact: Coronary thrombi were analyzed from ami patients.
#   ID: d17f54f4-cf5b-4401-a781-b489db3520b6
# ----------------------------------
#
#
# --- DEBUG: Graph Search Output ---
# Query: coronary thrombosis history
# Results:
# - Fact: Coronary thromboembolic events tend to be recurrent, multiple, and unpredictable in patients with coronary artery embolism (ce).
#   ID: b7b3b8b9-0fdb-4675-8e68-fa27f6d044dd
# - Fact: The 46-year-old woman had a family history of premature coronary disease.
#   ID: a3f7d390-ddb8-41be-ab2b-b0b764c8498c
# - Fact: Acute coronary syndromes in the presence of coronary-lung fistulas should be considered for coronary steal phenomenon.
#   ID: b39ac8b7-f44d-4bce-8a6c-171a66574368
# - Fact: Coronary artery embolism (ce) is an important nonatherosclerotic etiology of acute myocardial infarction (ami).
#   ID: b402d8c2-544e-4a21-86d8-a5c7c7d0c242
# - Fact: Coronary thrombi were analyzed from ami patients.
#   ID: d17f54f4-cf5b-4401-a781-b489db3520b6
# - Fact: The right coronary artery (rca) anomalously originates from the left coronary sinus.
#   ID: db80be59-1c5e-4ade-915c-099b7c36435f
# - Fact: Cardiology is a category related to coronary artery embolism.
#   ID: b1fede45-9597-4dd6-ac0b-655a3c2e3445
# - Fact: Coronary thrombi were retrieved between 2015 and 2019.
#   ID: 4dbd4ac5-267c-4edf-bcc2-aee6e9d33029
# - Fact: Coronary computed tomography angiography demonstrated an anomalous RCA arising from the left coronary sinus.
#   ID: 94195c5d-a271-4c4d-926d-e20f444f7738
# - Fact: Treatment of coronary steal phenomenon in cases of coronary-lung fistulas can include fistula embolization.
#   ID: 4fbebb3f-da2d-4c7d-841e-51e831ca3f5b
# ----------------------------------
#
# I apologize, but I was unable to generate a comprehensive timeline related to coronary thrombi using the knowledge graph tool. The tool provided individual facts, but not the historical progression of discoveries and treatments over time that would allow for the creation of a timeline.
#
# Would you like me to try a different approach or provide information in a different format?
