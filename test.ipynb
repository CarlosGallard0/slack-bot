# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings

load_dotenv(override=True)


model_name = os.getenv("MODEL_NAME", "gpt-3.5-turbo")
temperature = float(os.getenv("MODEL_TEMPERATURE", "0"))
project_id = os.getenv("PROJECT_ID")
location = os.getenv("LOCATION", "us-west1")
api_key = os.getenv("VERTEX_API_KEY")



llm = ChatGoogleGenerativeAI(
                model=model_name,
                temperature=temperature,
                project=project_id,
                location=location,
                api_key=api_key,
                vertexai=True,
            )


response = llm.invoke("Hello, world!")
print(response)


embeddings = GoogleGenerativeAIEmbeddings(
                model="text-embedding-005",
                project=project_id,
                location=location,
                api_key=api_key
            )


response = embeddings.embed_query("Hello, world!")
print(response)

# %%
from src.core.deep_agents.graphiti import GraphitiClient

graph_client = GraphitiClient()
await graph_client.initialize()
response = await graph_client.search("National Association of Doctors and Hospital Cardiologists (ANMCO)")
response

# %%
from src.rag.graphiti import GraphitiClient

graph_client = GraphitiClient()
await graph_client.initialize()
response = await graph_client.search("name: bicuspid aortic valve")
response
# Out:
# [{'fact': 'Patient 3 has a known bicuspid aortic valve.',
#   'uuid': 'd4b3043e-6f43-4538-8563-3a32db6003af',
#   'valid_at': '2026-01-14 20:10:13.507235+00:00',
#   'invalid_at': None,
#   'source_node_uuid': '4906ef4e-7bb7-4fd8-b765-7a913f906aa9',
#   'source_title': 'new_docs/41340977_Multiple pseudoaneurysms in complicated infective endocarditis importance of the Yin-Yang sign and m.pdf_3_1768421413.507181'},
#  {'fact': 'Bicuspid aortic valve is a cardiovascular anomaly associated with coarctation of the aorta.',
#   'uuid': '7658042d-b1b3-499c-affe-9d8aa3134efe',
#   'valid_at': '2026-01-14 19:52:39.820118+00:00',
#   'invalid_at': '2026-01-14 20:10:15.511766+00:00',
#   'source_node_uuid': 'a79732f8-8849-4396-92bd-e4095816c8b2',
#   'source_title': 'new_docs/41356867_An Unusual Case of Coarctation of the Aorta Repair A 35-Year Follow-Up.pdf_3_1768420359.820097'},
#  {'fact': 'Patient 1 was diagnosed with stenosis and regurgitation of a bicuspid aortic valve (BAV).',
#   'uuid': 'f8c20bd2-383e-4413-be82-2c71cf4a22d4',
#   'valid_at': '2026-01-14 20:10:15.511766+00:00',
#   'invalid_at': None,
#   'source_node_uuid': '065afcd8-19d9-42da-b81e-77345f2a2825',
#   'source_title': 'new_docs/41340977_Multiple pseudoaneurysms in complicated infective endocarditis importance of the Yin-Yang sign and m.pdf_1_1768421415.511708'},
#  {'fact': 'The patient underwent mechanical aortic valve replacement.',
#   'uuid': '4aead017-956e-47c2-9dd5-f4c834939b3b',
#   'valid_at': '2026-01-14 20:10:16.012991+00:00',
#   'invalid_at': None,
#   'source_node_uuid': 'a79732f8-8849-4396-92bd-e4095816c8b2',
#   'source_title': 'new_docs/41340977_Multiple pseudoaneurysms in complicated infective endocarditis importance of the Yin-Yang sign and m.pdf_2_1768421416.012968'},
#  {'fact': 'TAVI is T ranscatheter aortic valve implantation',
#   'uuid': 'ac866c87-a0f8-4533-a2ce-b72eec548f8c',
#   'valid_at': '2026-01-14 19:44:52.491482+00:00',
#   'invalid_at': None,
#   'source_node_uuid': '6f34503a-709e-402e-9f95-6f08387d7ca5',
#   'source_title': 'new_docs/41367775_Prognostic value of left atrioventricular coupling index in patients undergoing transcatheter aortic.pdf_1_1768419892.491418'},
#  {'fact': 'An ascending aortic aneurysm was treated with a mechanical aortic valve replacement.',
#   'uuid': '938f4aa3-5912-49d4-9aba-953ff2154eaa',
#   'valid_at': '2016-01-14 00:00:00+00:00',
#   'invalid_at': None,
#   'source_node_uuid': '65c75894-c4f3-43fa-9644-72a217c2e112',
#   'source_title': 'new_docs/41340977_Multiple pseudoaneurysms in complicated infective endocarditis importance of the Yin-Yang sign and m.pdf_2_1768421416.012968'},
#  {'fact': 'Atrioventricular septal defects (AVSDs) are characterized by abnormalities involving the atrioventricular valves.',
#   'uuid': '5143b6c2-2af3-4348-8638-d8404c0a0b92',
#   'valid_at': '2026-01-14 19:46:04.295632+00:00',
#   'invalid_at': '2026-01-14 19:54:59.493738+00:00',
#   'source_node_uuid': '9a976139-5386-4d7a-9724-ef9cd96246b8',
#   'source_title': 'new_docs/41346806_Case Report Concurrent atrial and ventricular septal defect in a young Sphynx cat.pdf_0_1768419964.295582'},
#  {'fact': 'Inflammation is related to aortic valve hemodynamics.',
#   'uuid': '0dc37599-d1ab-4e7e-9e4e-6a0a0291c036',
#   'valid_at': '2026-01-14 19:55:47.467164+00:00',
#   'invalid_at': '2026-01-14 20:33:41.915707+00:00',
#   'source_node_uuid': 'bf7d0d85-e8fb-4309-901d-b0a701c01c51',
#   'source_title': 'new_docs/41377627_Associations of Inflammatory and Osteogenic Activities in Epicardial Adipose Tissue With Aortic Valv.pdf_5_1768420547.467102'},
#  {'fact': 'Atrioventricular septal defects (AVSDs) are characterized by abnormalities involving the atrioventricular septum.',
#   'uuid': '8cacc32d-cf1f-47fc-b354-78d08df8a20b',
#   'valid_at': '2026-01-14 19:46:04.295632+00:00',
#   'invalid_at': None,
#   'source_node_uuid': '9a976139-5386-4d7a-9724-ef9cd96246b8',
#   'source_title': 'new_docs/41346806_Case Report Concurrent atrial and ventricular septal defect in a young Sphynx cat.pdf_0_1768419964.295582'},
#  {'fact': 'Aortic valve area index is part of echocardiographic data.',
#   'uuid': 'fb0fc62c-0922-463d-912d-0e6736301078',
#   'valid_at': '2026-01-14 19:55:46.464668+00:00',
#   'invalid_at': None,
#   'source_node_uuid': 'a5ad1be2-cd68-482b-9d68-f59fb206fd97',
#   'source_title': 'new_docs/41377627_Associations of Inflammatory and Osteogenic Activities in Epicardial Adipose Tissue With Aortic Valv.pdf_3_1768420546.464627'}]

# %%
from src.core.deep_agent import AgentCore
agent = AgentCore()

result = await agent.ask_async(
    "generate a timeline related to National Association of Doctors and Hospital Cardiologists (ANMCO)"
    )

print(result)
# for msg in result["messages"]:
#     print(msg.pretty_print())

# %%
from src.core.deep_agent import AgentCore
agent = AgentCore()

result = await agent.ask_async(
    "Generate a timeline related to coronary thrombi, use the knowledge graph tool"
    )

print(result)
# for msg in result["messages"]:
#     print(msg.pretty_print())

# %%
from src.core.deterministic_agent.d_agent import DeterministicAgent

# Initialize the agent
agent = DeterministicAgent()

# Run the query asynchronously
result = await agent.ask_async("Generate a timeline related to coronary thrombi, use the knowledge graph tool")

print(result)
# Out:
# {'answer': '*Timeline*\nThe provided research does not contain specific chronological data (dates, years of discovery) to construct a traditional historical timeline. However, based on the information provided, a conceptual timeline of understanding related to coronary thrombi can be synthesized:\n\n*   **Cardiovascular disease** is understood to encompass **thrombotic disease**.\n*   **Coronary artery aneurysms** are recognized as closely related to **coronary artery disease**.\n*   **Saccular aneurysms** are identified as particularly prone to **thrombosis** and rupture.\n*   These aneurysms, through thrombosis, can manifest clinically as **acute coronary syndrome**.\n*   For thrombotic events within the **thrombolysis window**, management includes administration of **intravenous recombinant tissue plasminogen activator**.\n*   This thrombolytic treatment is subsequently followed by **coronary intervention**.\n\n*Limitations*\nThis research is limited to data from the Medical Knowledge Graph and covers only the year 2024, potentially omitting relevant historical context or findings from other specialized databases.', 'sources': '', 'logs': ''}
