# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings

load_dotenv(override=True)


model_name = os.getenv("MODEL_NAME", "gpt-3.5-turbo")
temperature = float(os.getenv("MODEL_TEMPERATURE", "0"))
project_id = os.getenv("PROJECT_ID")
location = os.getenv("LOCATION", "us-west1")
api_key = os.getenv("VERTEX_API_KEY")



llm = ChatGoogleGenerativeAI(
                model=model_name,
                temperature=temperature,
                project=project_id,
                location=location,
                api_key=api_key,
                vertexai=True,
            )


response = llm.invoke("Hello, world!")
print(response)


embeddings = GoogleGenerativeAIEmbeddings(
                model="text-embedding-005",
                project=project_id,
                location=location,
                api_key=api_key
            )


response = embeddings.embed_query("Hello, world!")
print(response)

# %%
from src.core.graphiti import GraphitiClient

graph_client = GraphitiClient()
await graph_client.initialize()
response = await graph_client.search("National Association of Doctors and Hospital Cardiologists (ANMCO)")
response

# %%
from src.core.deep_agent import AgentCore
agent = AgentCore()

result = await agent.ask_async(
    "tell me about the National Association of Doctors and Hospital Cardiologists, use the knowledge graph tool"
    )

for msg in result["messages"]:
    print(msg.pretty_print())
# Out:
# ================================ Human Message =================================
#
# tell me about the National Association of Doctors and Hospital Cardiologists, use the knowledge graph tool
# None
# ================================== Ai Message ==================================
# Tool Calls:
#   task (fcbb9979-2a95-4fd8-a0cf-8fb2fdaecb36)
#  Call ID: fcbb9979-2a95-4fd8-a0cf-8fb2fdaecb36
#   Args:
#     subagent_type: graph_search
#     description: Tell me about the National Association of Doctors and Hospital Cardiologists.
# None
# ================================= Tool Message =================================
# Name: task
#
# The National Association of Doctors and Hospital Cardiologists, also referred to as ANMCO, disseminated a survey to hospital cardiology operative units. These units were identified through the 8th census of cardiological structures in Italy.
# None
# ================================== Ai Message ==================================
#
# The National Association of Doctors and Hospital Cardiologists, also known as ANMCO, conducted a survey that was distributed to hospital cardiology operative units. These units were identified through the 8th census of cardiological structures in Italy.
# None
